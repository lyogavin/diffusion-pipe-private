# %% [markdown]
# # download epochs

# %%
repoid = "animaaillc/godmodeai_wan_punch"

epoch_start = 170
epoch_end = 450
step = 15

lora_base_path = "~/ComfyUI/models/loras/godmodeai_wan_punch"

# !mkdir -p {lora_base_path}

# %%
# %cd {lora_base_path}
# Out:
# /root/ComfyUI/models/loras/godmodeai_wan_punch

# %%
import os
for epoch in range(epoch_start, epoch_end+step, step):
    if os.path.exists(f"./epoch{epoch}") and os.path.exists(f"./epoch{epoch}/adapter_model.safetensors"):
        print(f"./epoch{epoch} exists, skipping")
        continue
    # !huggingface-cli download --local-dir ./ {repoid} epoch{epoch}/adapter_model.safetensors
# Out:
# ./epoch170 exists, skipping
# ./epoch185 exists, skipping
# ./epoch200 exists, skipping
# ./epoch215 exists, skipping
# ./epoch230 exists, skipping
# ./epoch245 exists, skipping
# ./epoch260 exists, skipping
# ./epoch275 exists, skipping
# ./epoch290 exists, skipping
# ./epoch305 exists, skipping
# ./epoch320 exists, skipping
# ./epoch335 exists, skipping
# ./epoch350 exists, skipping
# Downloading 'epoch365/adapter_model.safetensors' to '.cache/huggingface/download/epoch365/WOf-g4Iw_GWHfmVY1wAN9cjZQSM=.e050d7b4162ec97eef0d8e2a12af9caefb7d2b96e83b93baa7a1c0ab4737d0bc.incomplete'
# Xet Storage is enabled for this repo. Downloading file from Xet Storage..
# epoch365/adapter_model.safetensors: 100%|████| 307M/307M [00:03<00:00, 93.9MB/s]
# Download complete. Moving file to epoch365/adapter_model.safetensors
# epoch365/adapter_model.safetensors
# ./epoch380 exists, skipping
# ./epoch395 exists, skipping
# ./epoch410 exists, skipping
# ./epoch425 exists, skipping
# ./epoch440 exists, skipping
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/utils/_http.py", line 409, in hf_raise_for_status
#     response.raise_for_status()
#   File "/opt/conda/lib/python3.11/site-packages/requests/models.py", line 1024, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/animaaillc/godmodeai_wan_punch/resolve/main/epoch455/adapter_model.safetensors
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/bin/huggingface-cli", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/commands/huggingface_cli.py", line 59, in main
#     service.run()
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/commands/download.py", line 153, in run
#     print(self._download())  # Print path to downloaded files
#           ^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/commands/download.py", line 166, in _download
#     return hf_hub_download(
#            ^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/file_download.py", line 988, in hf_hub_download
#     return _hf_hub_download_to_local_dir(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/file_download.py", line 1222, in _hf_hub_download_to_local_dir
#     (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = _get_metadata_or_catch_error(
#                                                                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/file_download.py", line 1533, in _get_metadata_or_catch_error
#     metadata = get_hf_file_metadata(
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/file_download.py", line 1450, in get_hf_file_metadata
#     r = _request_wrapper(
#         ^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/file_download.py", line 286, in _request_wrapper
#     response = _request_wrapper(
#                ^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/file_download.py", line 310, in _request_wrapper
#     hf_raise_for_status(response)
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/utils/_http.py", line 420, in hf_raise_for_status
#     raise _format(EntryNotFoundError, message, response) from e
# huggingface_hub.errors.EntryNotFoundError: 404 Client Error. (Request ID: Root=1-683ccca0-559e67293776783d2d3072b1;a2d7d87b-778a-4cd2-bcb4-f1802880e83e)
#
# Entry Not Found for url: https://huggingface.co/animaaillc/godmodeai_wan_punch/resolve/main/epoch455/adapter_model.safetensors.

# %%
from tqdm import tqdm
manual_checks = [] #155, 160, 165, 170, 175, 180, 190, 255, 265, 270]

import os
for epoch in tqdm(manual_checks):
    if os.path.exists(f"./epoch{epoch}") and os.path.exists(f"./epoch{epoch}/adapter_model.safetensors"):
        print(f"./epoch{epoch} exists, skipping")
        continue
    # !huggingface-cli download --local-dir ./ {repoid} epoch{epoch}/adapter_model.safetensors

# %% [markdown]
# # eval each epoch

# %%
# %cd /root/diffusion-pipe/data/
# Out:
# /root/diffusion-pipe/data

# %%
move = "Punch"

#characters = ["panda warrior with red cape", 
#              #"lion knight with gold armor"
#             ]


epoch_start = 170
epoch_end = 450
step = 15

# %%
lora_path_move = lora_base_path.split("/")[-1]

lora_path_move
# Out:
# 'godmodeai_wan_punch'

# %%
for epoch in range(epoch_start, epoch_end+step, step):
    #for char in characters:
    char = "Panda Warrior"
    print(f"evaling {epoch}")
    epoch_path = f"{lora_path_move}/epoch{epoch}/adapter_model.safetensors"
    prompt = f'''Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a strong, muscular build with distinctive black and white fur markings and characteristic panda facial features with dark patches around the eyes. He wears a flowing red cape that drapes over his shoulders, a black martial arts belt around his waist, and red hand wraps or fingerless gloves. He is barefoot with visible paw pads.
The panda character stands in a dynamic fighting stance. He executes a repetitive, swift straight punch (jab) with his right arm (viewer's left), which extends directly forward with a slight torso rotation, then retracts smoothly back to his stance. His red cape shifts subtly with the punching motion. His left arm remains bent in a guard position near his chest. This is a classic, looping fighting game punch animation.
The background is a solid, vibrant magenta. The overall visual style is that of a 16-bit era arcade fighting game sprite, with clearly defined pixels and limited color palette animation.'''

    prompt_file = "./tmp_prompt.txt"
    with open(prompt_file, 'w') as fp:
        fp.write(prompt)
        fp.flush()
        
    short_char = char.split(" ")[0]
    saving_postfix = f"_{epoch}_{short_char}.mp4"
    upload_path = f"epoch{epoch}/epoch{epoch}"
    repo = repoid
    width = 640
    height = 400
    frames = 10

    print(f"to run: python comfyui_workflow_submitter.py --lora {epoch_path}  --prompt-file {prompt_file} --postfix {saving_postfix} --hf-repo {repo} --hf-path {upload_path} --server 38.109.254.225:46531 --width {width} --height {height} --num-frames {frames}")
    
    # !python comfyui_workflow_submitter.py --lora {epoch_path}  --prompt-file {prompt_file} --postfix {saving_postfix} --hf-repo {repo} --hf-path {upload_path} --server 38.109.254.225:46531 --width {width} --height {height} --num-frames {frames}
# Out:
# evaling 170
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch170/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _170_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch170/epoch170 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch170/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: 412ee3a5-8d49-4a06-9d0a-472b9628a5da
# Waiting for completion of prompt 412ee3a5-8d49-4a06-9d0a-472b9628a5da...
# Prompt 412ee3a5-8d49-4a06-9d0a-472b9628a5da completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00211.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00211.mp4
# Added postfix to filename: epoch170/epoch170__170_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch170/epoch170__170_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00211.mp4
# File size: 0.09 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683ccd45-603bc89c2385454f3b6e5cd7;ea4b4fe1-dae3-4988-a68f-2137055f4f2a)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00211.mp4 to animaaillc/godmodeai_wan_punch/epoch170/epoch170__170_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00211.mp4 to animaaillc/godmodeai_wan_punch/epoch170/epoch170__170_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch170/epoch170__170_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 185
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch185/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _185_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch185/epoch185 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch185/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: 8226dcde-1d3f-4755-a86b-311fb1495346
# Waiting for completion of prompt 8226dcde-1d3f-4755-a86b-311fb1495346...
# Prompt 8226dcde-1d3f-4755-a86b-311fb1495346 completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00212.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00212.mp4
# Added postfix to filename: epoch185/epoch185__185_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch185/epoch185__185_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00212.mp4
# File size: 0.08 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683ccdc0-7ef26a273b2517be55a555ee;1a457996-7d8b-4a05-9ff1-b297d28689c1)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00212.mp4 to animaaillc/godmodeai_wan_punch/epoch185/epoch185__185_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00212.mp4 to animaaillc/godmodeai_wan_punch/epoch185/epoch185__185_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch185/epoch185__185_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 200
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch200/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _200_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch200/epoch200 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch200/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: a5d607a1-2b57-4192-9691-f8a5a8588102
# Waiting for completion of prompt a5d607a1-2b57-4192-9691-f8a5a8588102...
# Prompt a5d607a1-2b57-4192-9691-f8a5a8588102 completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00213.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00213.mp4
# Added postfix to filename: epoch200/epoch200__200_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch200/epoch200__200_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00213.mp4
# File size: 0.08 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cce39-33978c737331b28702ae0287;36a4fad6-e41b-49aa-8985-634d4c673567)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00213.mp4 to animaaillc/godmodeai_wan_punch/epoch200/epoch200__200_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00213.mp4 to animaaillc/godmodeai_wan_punch/epoch200/epoch200__200_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch200/epoch200__200_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 215
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch215/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _215_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch215/epoch215 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch215/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: e539e2ad-6e36-4926-ba20-9c857b0936eb
# Waiting for completion of prompt e539e2ad-6e36-4926-ba20-9c857b0936eb...
# Prompt e539e2ad-6e36-4926-ba20-9c857b0936eb completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00214.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00214.mp4
# Added postfix to filename: epoch215/epoch215__215_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch215/epoch215__215_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00214.mp4
# File size: 0.08 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cceb2-4661dffd5d64fab90c33b328;711faa2c-cf82-428d-98c1-1692afbea661)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00214.mp4 to animaaillc/godmodeai_wan_punch/epoch215/epoch215__215_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00214.mp4 to animaaillc/godmodeai_wan_punch/epoch215/epoch215__215_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch215/epoch215__215_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 230
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch230/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _230_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch230/epoch230 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch230/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: f4b24961-f9c0-4250-85c5-459527c59070
# Waiting for completion of prompt f4b24961-f9c0-4250-85c5-459527c59070...
# Prompt f4b24961-f9c0-4250-85c5-459527c59070 completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00215.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00215.mp4
# Added postfix to filename: epoch230/epoch230__230_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch230/epoch230__230_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00215.mp4
# File size: 0.08 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683ccf2b-47ad88664c6333375ad12744;cc8704aa-a2de-4da4-b58f-614ad22d1cfa)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00215.mp4 to animaaillc/godmodeai_wan_punch/epoch230/epoch230__230_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00215.mp4 to animaaillc/godmodeai_wan_punch/epoch230/epoch230__230_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch230/epoch230__230_Panda.mp4
# Pipeline completed successfully!
# evaling 245
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch245/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _245_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch245/epoch245 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch245/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: 6d51029b-edc1-4baf-a4bb-34f1ac736d4b
# Waiting for completion of prompt 6d51029b-edc1-4baf-a4bb-34f1ac736d4b...
# Prompt 6d51029b-edc1-4baf-a4bb-34f1ac736d4b completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00216.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00216.mp4
# Added postfix to filename: epoch245/epoch245__245_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch245/epoch245__245_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00216.mp4
# File size: 0.09 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683ccfa3-0dd587c7047c31df4f3938b3;21c9737c-7563-49d7-b9a8-bba9246d588f)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00216.mp4 to animaaillc/godmodeai_wan_punch/epoch245/epoch245__245_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00216.mp4 to animaaillc/godmodeai_wan_punch/epoch245/epoch245__245_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch245/epoch245__245_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 260
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch260/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _260_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch260/epoch260 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch260/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: 2bf9dca4-abe2-49dd-8fda-e3e33817e17d
# Waiting for completion of prompt 2bf9dca4-abe2-49dd-8fda-e3e33817e17d...
# Prompt 2bf9dca4-abe2-49dd-8fda-e3e33817e17d completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00217.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00217.mp4
# Added postfix to filename: epoch260/epoch260__260_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch260/epoch260__260_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00217.mp4
# File size: 0.08 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cd01e-6733ef3b278f4caf5b7d5ba8;33c26098-3730-4ea8-b5eb-1bda112031b6)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00217.mp4 to animaaillc/godmodeai_wan_punch/epoch260/epoch260__260_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00217.mp4 to animaaillc/godmodeai_wan_punch/epoch260/epoch260__260_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch260/epoch260__260_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 275
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch275/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _275_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch275/epoch275 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch275/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: 0ea47dc1-90c7-4df7-9f80-1e7a1d656582
# Waiting for completion of prompt 0ea47dc1-90c7-4df7-9f80-1e7a1d656582...
# Prompt 0ea47dc1-90c7-4df7-9f80-1e7a1d656582 completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00218.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00218.mp4
# Added postfix to filename: epoch275/epoch275__275_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch275/epoch275__275_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00218.mp4
# File size: 0.09 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cd099-5385d9e61e34ea177123c702;7737c3f8-8191-4f00-9255-d6bdd2a2f76a)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00218.mp4 to animaaillc/godmodeai_wan_punch/epoch275/epoch275__275_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00218.mp4 to animaaillc/godmodeai_wan_punch/epoch275/epoch275__275_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch275/epoch275__275_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 290
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch290/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _290_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch290/epoch290 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch290/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: 3fbf3670-e8a1-4681-af46-2fea59317fad
# Waiting for completion of prompt 3fbf3670-e8a1-4681-af46-2fea59317fad...
# Prompt 3fbf3670-e8a1-4681-af46-2fea59317fad completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00219.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00219.mp4
# Added postfix to filename: epoch290/epoch290__290_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch290/epoch290__290_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00219.mp4
# File size: 0.10 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cd115-33e0e2e046020e1b5de01b12;23c18238-7d72-40e6-b107-6a2389af5fae)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00219.mp4 to animaaillc/godmodeai_wan_punch/epoch290/epoch290__290_Panda.mp4...
# Uploading...: 100%|███████████████████████████| 101k/101k [00:00<00:00, 101kB/s]
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00219.mp4 to animaaillc/godmodeai_wan_punch/epoch290/epoch290__290_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch290/epoch290__290_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 305
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch305/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _305_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch305/epoch305 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch305/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: 0a53f21b-d664-4255-bfc6-ea4db7792068
# Waiting for completion of prompt 0a53f21b-d664-4255-bfc6-ea4db7792068...
# Prompt 0a53f21b-d664-4255-bfc6-ea4db7792068 completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00220.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00220.mp4
# Added postfix to filename: epoch305/epoch305__305_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch305/epoch305__305_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00220.mp4
# File size: 0.05 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cd18e-23e21cf50666e8337d88ccc6;89d24981-9d59-4c11-98f5-e2dfe50a4dbc)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00220.mp4 to animaaillc/godmodeai_wan_punch/epoch305/epoch305__305_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00220.mp4 to animaaillc/godmodeai_wan_punch/epoch305/epoch305__305_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch305/epoch305__305_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 320
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch320/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _320_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch320/epoch320 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch320/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: b05ad62a-a3a8-411c-b27a-4935d4dd4e01
# Waiting for completion of prompt b05ad62a-a3a8-411c-b27a-4935d4dd4e01...
# Prompt b05ad62a-a3a8-411c-b27a-4935d4dd4e01 completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00221.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00221.mp4
# Added postfix to filename: epoch320/epoch320__320_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch320/epoch320__320_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00221.mp4
# File size: 0.06 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cd207-6b206fa0235e34c6216e0dda;850b8dc2-d92d-442f-ae81-92630990dac7)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00221.mp4 to animaaillc/godmodeai_wan_punch/epoch320/epoch320__320_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00221.mp4 to animaaillc/godmodeai_wan_punch/epoch320/epoch320__320_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch320/epoch320__320_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 335
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch335/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _335_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch335/epoch335 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch335/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: 97815d2f-330d-4172-9a67-f1c76b20d0e6
# Waiting for completion of prompt 97815d2f-330d-4172-9a67-f1c76b20d0e6...
# Prompt 97815d2f-330d-4172-9a67-f1c76b20d0e6 completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00222.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00222.mp4
# Added postfix to filename: epoch335/epoch335__335_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch335/epoch335__335_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00222.mp4
# File size: 0.05 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cd280-30471ca67d54e19258277ff5;6f6815e5-9afb-42a2-8b52-cea049164c3b)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00222.mp4 to animaaillc/godmodeai_wan_punch/epoch335/epoch335__335_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00222.mp4 to animaaillc/godmodeai_wan_punch/epoch335/epoch335__335_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch335/epoch335__335_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 350
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch350/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _350_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch350/epoch350 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch350/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: 61ea5c1b-a5a7-4ba4-9fac-c92d78bbe7c2
# Waiting for completion of prompt 61ea5c1b-a5a7-4ba4-9fac-c92d78bbe7c2...
# Prompt 61ea5c1b-a5a7-4ba4-9fac-c92d78bbe7c2 completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00223.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00223.mp4
# Added postfix to filename: epoch350/epoch350__350_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch350/epoch350__350_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00223.mp4
# File size: 0.08 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cd2f9-69cad8b309e6710b609eb09f;fae1fda1-0297-41bc-b402-5b45941e301c)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00223.mp4 to animaaillc/godmodeai_wan_punch/epoch350/epoch350__350_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00223.mp4 to animaaillc/godmodeai_wan_punch/epoch350/epoch350__350_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch350/epoch350__350_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 365
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch365/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _365_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch365/epoch365 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch365/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: 9d8de743-f86e-48f7-98da-8635be3233d1
# Waiting for completion of prompt 9d8de743-f86e-48f7-98da-8635be3233d1...
# Prompt 9d8de743-f86e-48f7-98da-8635be3233d1 completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00224.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00224.mp4
# Added postfix to filename: epoch365/epoch365__365_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch365/epoch365__365_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00224.mp4
# File size: 0.09 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cd373-7becaa7d1dc4e23009eb4607;a68bd531-be92-43ee-84fc-fc9c6392c414)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00224.mp4 to animaaillc/godmodeai_wan_punch/epoch365/epoch365__365_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00224.mp4 to animaaillc/godmodeai_wan_punch/epoch365/epoch365__365_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch365/epoch365__365_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 380
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch380/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _380_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch380/epoch380 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch380/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: 88750439-7e72-4861-a01a-dfc0a10c944f
# Waiting for completion of prompt 88750439-7e72-4861-a01a-dfc0a10c944f...
# Prompt 88750439-7e72-4861-a01a-dfc0a10c944f completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00225.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00225.mp4
# Added postfix to filename: epoch380/epoch380__380_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch380/epoch380__380_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00225.mp4
# File size: 0.09 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cd3ee-7da16ce6596372597478e14d;d7235a1f-0d62-4a0a-93e7-ccfeb573f39f)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00225.mp4 to animaaillc/godmodeai_wan_punch/epoch380/epoch380__380_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00225.mp4 to animaaillc/godmodeai_wan_punch/epoch380/epoch380__380_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch380/epoch380__380_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 395
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch395/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _395_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch395/epoch395 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch395/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: bbf3cccb-d1b0-4d6f-baa1-01aeb264e0ae
# Waiting for completion of prompt bbf3cccb-d1b0-4d6f-baa1-01aeb264e0ae...
# Prompt bbf3cccb-d1b0-4d6f-baa1-01aeb264e0ae completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00226.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00226.mp4
# Added postfix to filename: epoch395/epoch395__395_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch395/epoch395__395_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00226.mp4
# File size: 0.09 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cd469-4ce2832006a1ed5976113f12;8bdb4063-df73-46f1-9cd0-d1e7162f31a0)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00226.mp4 to animaaillc/godmodeai_wan_punch/epoch395/epoch395__395_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00226.mp4 to animaaillc/godmodeai_wan_punch/epoch395/epoch395__395_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch395/epoch395__395_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 410
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch410/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _410_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch410/epoch410 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch410/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: ece72dac-fe1f-4dc9-b8c0-4845dfac131f
# Waiting for completion of prompt ece72dac-fe1f-4dc9-b8c0-4845dfac131f...
# Prompt ece72dac-fe1f-4dc9-b8c0-4845dfac131f completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00227.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00227.mp4
# Added postfix to filename: epoch410/epoch410__410_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch410/epoch410__410_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00227.mp4
# File size: 0.08 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cd4e2-20add23379fa0890766cbd53;d5abc193-1211-4ae9-a891-e54e7a0c5246)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00227.mp4 to animaaillc/godmodeai_wan_punch/epoch410/epoch410__410_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00227.mp4 to animaaillc/godmodeai_wan_punch/epoch410/epoch410__410_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch410/epoch410__410_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 425
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch425/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _425_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch425/epoch425 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch425/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: 62c30144-d64d-4f03-b631-85a3a4135465
# Waiting for completion of prompt 62c30144-d64d-4f03-b631-85a3a4135465...
# Prompt 62c30144-d64d-4f03-b631-85a3a4135465 completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00228.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00228.mp4
# Added postfix to filename: epoch425/epoch425__425_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch425/epoch425__425_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00228.mp4
# File size: 0.09 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cd55b-79e0900a75afd7357ab9a6a5;60405aab-da6b-4708-9b8e-8433985e914e)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00228.mp4 to animaaillc/godmodeai_wan_punch/epoch425/epoch425__425_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00228.mp4 to animaaillc/godmodeai_wan_punch/epoch425/epoch425__425_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch425/epoch425__425_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 440
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch440/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _440_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch440/epoch440 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch440/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# Workflow submitted successfully. Prompt ID: ce1825f9-4708-4c9e-aba7-2f8f13778977
# Waiting for completion of prompt ce1825f9-4708-4c9e-aba7-2f8f13778977...
# Prompt ce1825f9-4708-4c9e-aba7-2f8f13778977 completed successfully!
# Found result file at: /root/ComfyUI/output/WanVideo2_1_T2V_00229.mp4
# Copied result to: ./outputs/WanVideo2_1_T2V_00229.mp4
# Added postfix to filename: epoch440/epoch440__440_Panda.mp4
# Warning: No Hugging Face token provided
# Attempting to upload to repository: animaaillc/godmodeai_wan_punch
# Upload path: epoch440/epoch440__440_Panda.mp4
# Local file: ./outputs/WanVideo2_1_T2V_00229.mp4
# File size: 0.06 MB
# Auto-detecting repository type...
# Trying to access repo as type 'dataset'...
# ❌ Failed with repo_type='dataset': 404 Client Error. (Request ID: Root=1-683cd5d4-44d99f9f5f0ec12429299094;7e8148c5-6d16-43bf-943f-67caccbebab0)
#
# Repository Not Found for url: https://huggingface.co/api/datasets/animaaillc/godmodeai_wan_punch.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication
# Trying to access repo as type 'model'...
# ✅ Repository found as type 'model': animaaillc/godmodeai_wan_punch
# 🚀 Uploading ./outputs/WanVideo2_1_T2V_00229.mp4 to animaaillc/godmodeai_wan_punch/epoch440/epoch440__440_Panda.mp4...
# ✅ Successfully uploaded ./outputs/WanVideo2_1_T2V_00229.mp4 to animaaillc/godmodeai_wan_punch/epoch440/epoch440__440_Panda.mp4 (type: model)
# Upload result: https://huggingface.co/animaaillc/godmodeai_wan_punch/blob/main/epoch440/epoch440__440_Panda.mp4
# Pipeline completed successfully!
# WebSocket connection closed
# evaling 455
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_punch/epoch455/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _455_Panda.mp4 --hf-repo animaaillc/godmodeai_wan_punch --hf-path epoch455/epoch455 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 10
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_punch/epoch455/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Punch, Side view, 2D pixel art animation of a panda warrior character. He has a stron...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 10
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 10
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 400
# Error response content: {"error": {"type": "prompt_outputs_failed_validation", "message": "Prompt outputs failed validation", "details": "", "extra_info": {}}, "node_errors": {"56": {"errors": [{"type": "value_not_in_list", "message": "Value not in list", "details": "lora: 'godmodeai_wan_punch/epoch455/adapter_model.safetensors' not in (list of length 125)", "extra_info": {"input_name": "lora", "input_config": null, "received_value": "godmodeai_wan_punch/epoch455/adapter_model.safetensors"}}], "dependent_outputs": ["61", "30"], "class_type": "WanVideoLoraSelect"}}}
# ComfyUI error details: {'type': 'prompt_outputs_failed_validation', 'message': 'Prompt outputs failed validation', 'details': '', 'extra_info': {}}
# Node errors: {'56': {'errors': [{'type': 'value_not_in_list', 'message': 'Value not in list', 'details': "lora: 'godmodeai_wan_punch/epoch455/adapter_model.safetensors' not in (list of length 125)", 'extra_info': {'input_name': 'lora', 'input_config': None, 'received_value': 'godmodeai_wan_punch/epoch455/adapter_model.safetensors'}}], 'dependent_outputs': ['61', '30'], 'class_type': 'WanVideoLoraSelect'}}
# Error submitting workflow: 400 Client Error: Bad Request for url: http://38.109.254.225:46531/prompt
# Server address: 38.109.254.225:46531
# Base URL: http://38.109.254.225:46531
#
# Workflow summary:
#   Node 11: LoadWanVideoT5TextEncoder
#   Node 16: WanVideoTextEncode
#   Node 22: WanVideoModelLoader
#   Node 27: WanVideoSampler
#   Node 28: WanVideoDecode
#   Node 30: VHS_VideoCombine
#   Node 35: WanVideoTorchCompileSettings
#   Node 37: WanVideoEmptyEmbeds
#   Node 38: WanVideoVAELoader
#   Node 39: WanVideoBlockSwap
#   Node 45: WanVideoVRAMManagement
#   Node 56: WanVideoLoraSelect
#   Node 61: PreviewAny
# WebSocket connection closed
# Traceback (most recent call last):
#   File "/root/diffusion-pipe/data/comfyui_workflow_submitter.py", line 664, in <module>
#     main()
#     ^^^^^^
#   File "/root/diffusion-pipe/data/comfyui_workflow_submitter.py", line 621, in main
#     prompt_id = client.submit_workflow(workflow)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/diffusion-pipe/data/comfyui_workflow_submitter.py", line 112, in submit_workflow
#     response.raise_for_status()
#   File "/opt/conda/lib/python3.11/site-packages/requests/models.py", line 1024, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error: Bad Request for url: http://38.109.254.225:46531/prompt
