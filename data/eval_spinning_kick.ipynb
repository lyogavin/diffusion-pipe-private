# %% [markdown]
# # download epochs

# %%
repoid = "lyogavin/godmodeai_wan_spinningkick"

epoch_start = 170
epoch_end = 450
step = 15

lora_base_path = "~/ComfyUI/models/loras/godmodeai_wan_spinningkick"

# !mkdir -p {lora_base_path}

# %%
# %cd {lora_base_path}
# Out:
# /root/ComfyUI/models/loras/godmodeai_wan_spinningkick
# /opt/conda/lib/python3.11/site-packages/IPython/core/magics/osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /opt/conda/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os
for epoch in range(epoch_start, epoch_end+step, step):
    if os.path.exists(f"./epoch{epoch}") and os.path.exists(f"./epoch{epoch}/adapter_model.safetensors"):
        print(f"./epoch{epoch} exists, skipping")
        continue
    # !huggingface-cli download --local-dir ./ {repoid} epoch{epoch}/adapter_model.safetensors
# Out:
# ...
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:04<00:00, 65.2MB/s]
# Download complete. Moving file to epoch170/adapter_model.safetensors
# epoch170/adapter_model.safetensors
# ...
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:05<00:00, 60.4MB/s]
# Download complete. Moving file to epoch185/adapter_model.safetensors
# epoch185/adapter_model.safetensors
# ...
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:04<00:00, 66.0MB/s]
# Download complete. Moving file to epoch200/adapter_model.safetensors
# epoch200/adapter_model.safetensors
# ...
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:05<00:00, 60.2MB/s]
# Download complete. Moving file to epoch215/adapter_model.safetensors
# epoch215/adapter_model.safetensors
# ...
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:04<00:00, 61.6MB/s]
# Download complete. Moving file to epoch230/adapter_model.safetensors
# epoch230/adapter_model.safetensors
# ...

# %%
from tqdm import tqdm
manual_checks = [155, 160, 165, 170, 175, 180, 190, 255, 265, 270]

import os
for epoch in tqdm(manual_checks):
    if os.path.exists(f"./epoch{epoch}") and os.path.exists(f"./epoch{epoch}/adapter_model.safetensors"):
        print(f"./epoch{epoch} exists, skipping")
        continue
    # !huggingface-cli download --local-dir ./ {repoid} epoch{epoch}/adapter_model.safetensors

# %% [markdown]
# # eval each epoch

# %%
# %cd /root/diffusion-pipe/data/
# Out:
# /root/diffusion-pipe/data

# %%
move = "Spinning Kick"

#characters = ["panda warrior with red cape", 
#              #"lion knight with gold armor"
#             ]


epoch_start = 170
epoch_end = 450
step = 15

# %%
for epoch in range(epoch_start, epoch_end+step, step):
    #for char in characters:
    char = "Panda Warrior"
    print(f"evaling {epoch}")
    epoch_path = f"godmodeai_wan_spinningkick/epoch{epoch}/adapter_model.safetensors"
    prompt = f'''Game animation Spinning Kick, Pixel art animation, 2D side-view. A muscular panda warrior with distinctive black and white fur markings and a flowing red cape executes a dynamic spinning kick. He is barefoot with visible paw pads and wears a traditional black martial arts belt around his waist and red sparring gloves.
The sequence shows the panda character, initially with his back partially turned, in the midst of a powerful, high arcing kick with his right leg as his body rotates swiftly. His red cape billows and flows dramatically with the spinning motion. He completes a full spin with fluid movement, then lands solidly on both feet, transitioning smoothly into a fighting stance facing directly towards the viewer, paws defensively raised. The red cape settles gracefully around his shoulders. The background is a consistent, bright magenta. The animation style evokes classic 16-bit era fighting games, emphasizing fluid movement and impactful action.'''

    prompt_file = "./tmp_prompt.txt"
    with open(prompt_file, 'w') as fp:
        fp.write(prompt)
        fp.flush()
        
    short_char = char.split(" ")[0]
    saving_postfix = f"_{epoch}_{short_char}.mp4"
    upload_path = f"epoch{epoch}/epoch{epoch}"
    repo = repoid
    width = 640
    height = 400
    frames = 30

    print(f"to run: python comfyui_workflow_submitter.py --lora {epoch_path}  --prompt-file {prompt_file} --postfix {saving_postfix} --hf-repo {repo} --hf-path {upload_path} --server 38.109.254.225:46531 --width {width} --height {height} --num-frames {frames}")
    
    # !python comfyui_workflow_submitter.py --lora {epoch_path}  --prompt-file {prompt_file} --postfix {saving_postfix} --hf-repo {repo} --hf-path {upload_path} --server 38.109.254.225:46531 --width {width} --height {height} --num-frames {frames}
# Out:
# evaling 170
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_spinningkick/epoch170/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _170_Panda.mp4 --hf-repo lyogavin/godmodeai_wan_spinningkick --hf-path epoch170/epoch170 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 30
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_spinningkick/epoch170/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Spinning Kick, Pixel art animation, 2D side-view. A muscular panda warrior with disti...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 30
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 30
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# ...

# %%
#!mv ./epoch* ~/ComfyUI/models/loras/godmodeai_wan_spinningkick/
# !ls ~/ComfyUI/models/loras/godmodeai_wan_spinningkick/
# Out:
# epoch155  epoch175  epoch200  epoch255	epoch275  epoch335  epoch395  epoch455
# epoch160  epoch180  epoch215  epoch260	epoch290  epoch350  epoch410
# epoch165  epoch185  epoch230  epoch265	epoch305  epoch365  epoch425
# epoch170  epoch190  epoch245  epoch270	epoch320  epoch380  epoch440

# %%
for epoch in tqdm(manual_checks):
    #for char in characters:
    char = "Panda Warrior"
    print(f"evaling {epoch}")
    epoch_path = f"godmodeai_wan_spinningkick/epoch{epoch}/adapter_model.safetensors"
    prompt = f'''Game animation Spinning Kick, Pixel art animation, 2D side-view. A muscular panda warrior with distinctive black and white fur markings and a flowing red cape executes a dynamic spinning kick. He is barefoot with visible paw pads and wears a traditional black martial arts belt around his waist and red sparring gloves.
The sequence shows the panda character, initially with his back partially turned, in the midst of a powerful, high arcing kick with his right leg as his body rotates swiftly. His red cape billows and flows dramatically with the spinning motion. He completes a full spin with fluid movement, then lands solidly on both feet, transitioning smoothly into a fighting stance facing directly towards the viewer, paws defensively raised. The red cape settles gracefully around his shoulders. The background is a consistent, bright magenta. The animation style evokes classic 16-bit era fighting games, emphasizing fluid movement and impactful action.'''

    prompt_file = "./tmp_prompt.txt"
    with open(prompt_file, 'w') as fp:
        fp.write(prompt)
        fp.flush()
        
    short_char = char.split(" ")[0]
    saving_postfix = f"_{epoch}_{short_char}.mp4"
    upload_path = f"epoch{epoch}/epoch{epoch}"
    repo = repoid
    width = 640
    height = 400
    frames = 30

    print(f"to run: python comfyui_workflow_submitter.py --lora {epoch_path}  --prompt-file {prompt_file} --postfix {saving_postfix} --hf-repo {repo} --hf-path {upload_path} --server 38.109.254.225:46531 --width {width} --height {height} --num-frames {frames}")
    
    # !python comfyui_workflow_submitter.py --lora {epoch_path}  --prompt-file {prompt_file} --postfix {saving_postfix} --hf-repo {repo} --hf-path {upload_path} --server 38.109.254.225:46531 --width {width} --height {height} --num-frames {frames}
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# evaling 155
# to run: python comfyui_workflow_submitter.py --lora godmodeai_wan_spinningkick/epoch155/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _155_Panda.mp4 --hf-repo lyogavin/godmodeai_wan_spinningkick --hf-path epoch155/epoch155 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 30
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: godmodeai_wan_spinningkick/epoch155/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Spinning Kick, Pixel art animation, 2D side-view. A muscular panda warrior with disti...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 30
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 30
# Workflow validation completed
# WebSocket connection opened
# ...
