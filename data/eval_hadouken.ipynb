# %% [markdown]
# # download epochs

# %%
repoid = "lyogavin/godmodeai_wan_hadoukenv2"

epoch_start = 195
epoch_end = 210

epoch_start = 350
epoch_end = 400

# %%
# %cd ~/ComfyUI/models/loras
# Out:
# /root/ComfyUI/models/loras

# %%
import os
step = 15
for epoch in range(epoch_start, epoch_end+step, step):
    if os.path.exists(f"./epoch{epoch}") and os.path.exists(f"./epoch{epoch}/adapter_model.safetensors"):
        print(f"./epoch{epoch} exists, skipping")
        continue
    # !huggingface-cli download --local-dir ./ {repoid} epoch{epoch}/adapter_model.safetensors
# Out:
# ...
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:03<00:00, 83.7MB/s]
# Download complete. Moving file to epoch350/adapter_model.safetensors
# epoch350/adapter_model.safetensors
# ...
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:04<00:00, 75.3MB/s]
# Download complete. Moving file to epoch365/adapter_model.safetensors
# epoch365/adapter_model.safetensors
# ...
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:03<00:00, 81.6MB/s]
# Download complete. Moving file to epoch380/adapter_model.safetensors
# epoch380/adapter_model.safetensors
# ...
# adapter_model.safetensors: 100%|█████████████| 307M/307M [00:04<00:00, 67.1MB/s]
# Download complete. Moving file to epoch395/adapter_model.safetensors
# epoch395/adapter_model.safetensors
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/huggingface_hub/utils/_http.py", line 409, in hf_raise_for_status
#     response.raise_for_status()
# ...

# %% [markdown]
# # eval each epoch

# %%
# %cd /root/diffusion-pipe/data/
# Out:
# /root/diffusion-pipe/data

# %%
move = "Hadouken"

#characters = ["panda warrior with red cape", 
#              #"lion knight with gold armor"
#             ]


epoch_start = 190
epoch_end = 210

epoch_start = 350
epoch_end = 400

# %%
step = 15
for epoch in range(epoch_start, epoch_end+step, step):
    #for char in characters:
    print(f"evaling {epoch} - {char}")
    epoch_path = f"epoch{epoch}/adapter_model.safetensors"
    prompt = f'''Game animation Hadouken, A 2D pixel art animation of a muscular panda warrior, in a side view, reminiscent of classic 90s fighting games. He has black and white fur with distinctive panda markings around his eyes, wears a flowing red cape that billows dramatically, a black martial arts belt around his waist, and red fingerless fighting gloves. He is barefoot with visible paw pads.
The panda character performs a powerful energy projectile attack (like a Hadouken). He starts in a low, wide stance, brings his cupped paws back to his side as if gathering energy (perhaps with subtle glowing effects around his paws), then explosively thrusts both paws forward, palms open, launching the unseen projectile. His body recoils slightly from the force, and his red cape flows with the movement. The animation loop should be smooth.
The background is a solid, vibrant magenta. The overall aesthetic is retro, 16-bit era arcade style.'''

    prompt_file = "./tmp_prompt.txt"
    with open(prompt_file, 'w') as fp:
        fp.write(prompt)
        fp.flush()
        
    short_char = char.split(" ")[0]
    saving_postfix = f"_{epoch}_{short_char}.mp4"
    upload_path = f"epoch{epoch}/epoch{epoch}"
    repo = f"lyogavin/godmodeai_wan_hadoukenv2"
    width = 640
    height = 400
    frames = 21

    print(f"to run: python comfyui_workflow_submitter.py --lora {epoch_path}  --prompt-file {prompt_file} --postfix {saving_postfix} --hf-repo {repo} --hf-path {upload_path} --server 38.109.254.225:46531 --width {width} --height {height} --num-frames {frames}")
    
    # !python comfyui_workflow_submitter.py --lora {epoch_path}  --prompt-file {prompt_file} --postfix {saving_postfix} --hf-repo {repo} --hf-path {upload_path} --server 38.109.254.225:46531 --width {width} --height {height} --num-frames {frames}
# Out:
# evaling 350 - panda warrior with red cape
# to run: python comfyui_workflow_submitter.py --lora epoch350/adapter_model.safetensors  --prompt-file ./tmp_prompt.txt --postfix _350_panda.mp4 --hf-repo lyogavin/godmodeai_wan_hadoukenv2 --hf-path epoch350/epoch350 --server 38.109.254.225:46531 --width 640 --height 400 --num-frames 21
# Loaded prompt from file: ./tmp_prompt.txt
# Updated LoRA in node #56 to: epoch350/adapter_model.safetensors
# Updated positive prompt in node #16 to: Game animation Hadouken, A 2D pixel art animation of a muscular panda warrior, in a side view, remin...
# Updated width in node #37 to: 640
# Updated height in node #37 to: 400
# Updated num_frames in node #37 to: 21
# Validating workflow...
# Info: Node 37 width: 640
# Info: Node 37 height: 400
# Info: Node 37 num_frames: 21
# Workflow validation completed
# WebSocket connection opened
# Submitting workflow to http://38.109.254.225:46531/prompt...
# Workflow has 13 nodes
# Response status code: 200
# ...

# %%
# !ls ~/ComfyUI/models/loras
# Out:
# epoch110  epoch145  epoch165  epoch225	epoch35  epoch95
# epoch130  epoch150  epoch170  epoch255	epoch40  put_loras_here
# epoch135  epoch155  epoch175  epoch280	epoch45
# epoch140  epoch160  epoch195  epoch30	epoch60
